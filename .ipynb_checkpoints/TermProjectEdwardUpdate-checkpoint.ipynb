# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

from tensorflow.keras import datasets, layers, models

import pathlib
import random
import os

# %%
dataPath = '/s/bach/g/under/cutreap/Desktop/cs445/cell_images/'
dataRoot = pathlib.Path(dataPath)

# %%
imageDirs = []
for item in dataRoot.iterdir():
    imageDirs.append(item)

dataRoot = []
for path in imageDirs:
    dataRoot.append(pathlib.Path(path))

# %%
labeledImages = []
label = 0
classes = sorted(os.walk(dataPath).__next__()[1])
# List each sub-directory (the classes)
for c in classes:
    c_dir = os.path.join(dataPath, c)
    walk = os.walk(c_dir).__next__()
    # Add each image to the training set
    for sample in walk[2]:
        # Only keeps jpeg images
        if sample.endswith('.png') or sample.endswith('.jpeg'):
            labeledImages.append( (label, os.path.join(c_dir, sample)) )
    label += 1

# %%
labeledTrain = []
labeledTest = []
i = 0
for image in labeledImages:
    if(i < .8*len(labeledImages)):
        labeledTrain.append(image)
        i += 1
    else:
        labeledTest.append(image)
trainPaths = [x[1] for x in labeledTrain]
trainLabels = [x[0] for x in labeledTrain]
testPaths = [x[1] for x in labeledTest]
testLabels = [x[0] for x in labeledTest]
testSize = len(testLabels)
trainSize = len(trainLabels)

# %%
#trainPaths = []
#trainLabels = []
#testPaths = []
#testLabels = []
#for i in range(len(imagePaths)):
#    if(i < .8*len(imagePaths)):
#        trainPaths.append(imagePaths[i])
#        trainLabels.append(labels[i])
#    else:
#        testPaths.append(imagePaths[i])
#        testLabels.append(labels[i])

# %% [markdown]
# def loadAndPreprocessImage(path):
#   image = tf.read_file(path)
#   image = tf.image.decode_png(image, channels=3)
#   image = tf.image.resize_images(image, [128, 128])
#   image = image / 127.5 - 1.0  # normalize to [-1,1] range
#   return image

# %%
def prepDataForConvNet(imagePaths, labels, batch_size):
    # Convert to Tensor
    imagePaths = tf.convert_to_tensor(imagePaths, dtype=tf.string)
    labels = tf.convert_to_tensor(labels, dtype=tf.int32)
    # Build a TF Queue, shuffle data
    image, label = tf.train.slice_input_producer([imagePaths, labels],
                                                 shuffle=True)

    # Read images from disk
    image = tf.read_file(image)
    image = tf.image.decode_png(image, channels=CHANNELS)

    # Resize images to a common size
    image = tf.image.resize_images(image, [128, 128])
    
    

    # Normalize
    image = image * 1.0/127.5 - 1.0

    # Create batches
    X, Y = tf.train.batch([image, label], batch_size=batch_size,
                          capacity=batch_size * 8,
                          num_threads=4)

    return X, Y

# %%
learning_rate = 0.001
num_steps = 50
batchSize = 128
display_step = 1

# Network Parameters
dropout = 0.75 # Dropout, probability to keep units

# Image Parameters_
N_CLASSES = 2 # CHANGE HERE, total number of classes
IMG_HEIGHT = 128 # CHANGE HERE, the image height to be resized to
IMG_WIDTH = 128 # CHANGE HERE, the image width to be resized to
CHANNELS = 3 # The 3 color channels, change to 1 if grayscale

# %%
trainImages, trainLabels = prepDataForConvNet(trainPaths, trainLabels, batchSize)
testImages, testLabels = prepDataForConvNet(testPaths, testLabels, 1)
# Out:
# WARNING:tensorflow:From <ipython-input-7-ece6a30fbb0a>:7: slice_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(tuple(tensor_list)).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/input.py:374: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.range(limit).shuffle(limit).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/input.py:320: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/input.py:190: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/input.py:199: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/input.py:199: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/input.py:202: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From <ipython-input-7-ece6a30fbb0a>:24: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).

# %%
#trainPathDS = tf.data.Dataset.from_tensor_slices(trainPaths)
#trainImageDS = trainPathDS.map(loadAndPreprocessImage, num_parallel_calls=tf.data.experimental.AUTOTUNE)
#trainLabelDS = tf.data.Dataset.from_tensor_slices(tf.cast(trainLabels, tf.int64))
#trainDS = tf.data.Dataset.zip((trainImageDS, trainLabelDS))

#testPathDS = tf.data.Dataset.from_tensor_slices(testPaths)
#testImageDS = testPathDS.map(loadAndPreprocessImage, num_parallel_calls=tf.data.experimental.AUTOTUNE)
#testLabelDS = tf.data.Dataset.from_tensor_slices(tf.cast(testLabels, tf.int64))
#testDS = tf.data.Dataset.zip((testImageDS, testLabelDS))

# %%
# Create model
def conv_net(images, n_classes, dropout, reuse, is_training):
    # Define a scope for reusing the variables
    with tf.variable_scope('ConvNet', reuse=reuse):

        # Convolution Layer with 32 filters and a kernel size of 5
        conv1 = tf.layers.conv2d(images, 32, 5, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with kernel size of 2 and strides of 2
        conv1 = tf.layers.max_pooling2d(conv1, 5, 3)

        # Convolution Layer with 32 filters and a kernel size of 5
        conv2 = tf.layers.conv2d(conv1, 64, 3, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with kernel size of 2 and strides of 2 
        conv2 = tf.layers.max_pooling2d(conv2, 5, 3)
        
        conv3 = tf.layers.conv2d(conv2, 128, 3)
        conv3 = tf.layers.max_pooling2d(conv3, 3, 2)

        # Flatten the data to a 1-D vector for the fully connected layer
        fc1 = tf.contrib.layers.flatten(conv3)

        # Fully connected layer (in contrib folder for now)
        fc1 = tf.layers.dense(fc1, 1024)
        # Apply Dropout (if is_training is False, dropout is not applied)
        fc1 = tf.layers.dropout(fc1, rate=dropout, training=is_training)

        # Output layer, class prediction
        out = tf.layers.dense(fc1, n_classes)
        # Because 'softmax_cross_entropy_with_logits' already apply softmax,
        # we only apply softmax to testing network
        out = tf.nn.softmax(out) if not is_training else out

    return out

# %%
logits_train = conv_net(trainImages, N_CLASSES, dropout, reuse=False, is_training=True)
# Create another graph for testing that reuse the same weights
logits_test = conv_net(trainImages, N_CLASSES, dropout, reuse=True, is_training=False)


logits_test_test = conv_net(testImages, N_CLASSES, dropout, reuse=True, is_training=False)

# Define loss and optimizer (with train logits, for dropout to take effect)
loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
    logits=logits_train, labels=trainLabels))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(logits_test, 1), tf.cast(trainLabels, tf.int64))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

correct_pred_test = tf.equal(tf.argmax(logits_test_test, 1), tf.cast(testLabels, tf.int64))
accuracy_test = tf.reduce_mean(tf.cast(correct_pred_test, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Saver object
saver = tf.train.Saver()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    # Start the data queue
    tf.train.start_queue_runners()

    # Training cycle
    
    train_acc = 0;
    
    for step in range(1, num_steps+1):

        if step % display_step == 0:
            # Run optimization and calculate batch loss and accuracy
            _, loss, acc = sess.run([train_op, loss_op, accuracy])
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))
        else:
            # Only run the optimization op (backprop)
            sess.run(train_op)
            
            
    for step in range(1, (math.ceil(trainSize/batchSize) )+1):
        # Run optimization and calculate batch loss and accuracy
        acc3 = sess.run(accuracy)
        train_acc += acc3
        if step % 5 == 0:
            # Run optimization and calculate batch loss and accuracy
            print("Step " + str(step) + ", Training observing only Accuracy= " + str(acc3))
  
      
    train_acc = train_acc/(math.ceil(trainSize/batchSize) )
    test_accuracy = 0;
    for step in range(1, testSize + 1):
        acc2 = sess.run(accuracy_test)
        test_accuracy += acc2

        if step % 100 == 0:
            # Run optimization and calculate batch loss and accuracy
            print("Step " + str(step) + ", Testing Accuracy= " + str(acc2))

            
    test_accuracy = test_accuracy/testSize
    print("Optimization Finished! " + str(test_accuracy))
    # Save your model
    saver.save(sess, 'my_tf_model4')
# Out:
# WARNING:tensorflow:From <ipython-input-11-298035ad32ec>:7: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-11-298035ad32ec>:9: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-11-298035ad32ec>:23: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-11-298035ad32ec>:25: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-12-b0efb8fa2305>:34: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Step 1, Minibatch Loss= 0.7171, Training Accuracy= 0.625
# Step 2, Minibatch Loss= 3.2004, Training Accuracy= 0.570
# Step 3, Minibatch Loss= 0.7052, Training Accuracy= 0.570
# Step 4, Minibatch Loss= 1.9942, Training Accuracy= 0.398
# Step 5, Minibatch Loss= 1.1313, Training Accuracy= 0.352
# Step 6, Minibatch Loss= 0.6037, Training Accuracy= 0.641
# Step 7, Minibatch Loss= 0.7075, Training Accuracy= 0.672
# Step 8, Minibatch Loss= 0.6944, Training Accuracy= 0.695
# Step 9, Minibatch Loss= 0.7243, Training Accuracy= 0.625
# Step 10, Minibatch Loss= 0.6212, Training Accuracy= 0.648
# Step 11, Minibatch Loss= 0.5892, Training Accuracy= 0.758
# Step 12, Minibatch Loss= 0.6254, Training Accuracy= 0.719
# Step 13, Minibatch Loss= 0.6430, Training Accuracy= 0.633
# Step 14, Minibatch Loss= 0.6167, Training Accuracy= 0.680
# Step 15, Minibatch Loss= 0.5919, Training Accuracy= 0.672
# Step 16, Minibatch Loss= 0.5818, Training Accuracy= 0.641
# Step 17, Minibatch Loss= 0.6496, Training Accuracy= 0.680
# Step 18, Minibatch Loss= 0.6237, Training Accuracy= 0.695
# Step 19, Minibatch Loss= 0.5248, Training Accuracy= 0.711
# Step 20, Minibatch Loss= 0.5664, Training Accuracy= 0.781
# Step 21, Minibatch Loss= 0.6291, Training Accuracy= 0.648
# Step 22, Minibatch Loss= 0.5076, Training Accuracy= 0.766
# Step 23, Minibatch Loss= 0.5140, Training Accuracy= 0.797
# Step 24, Minibatch Loss= 0.5717, Training Accuracy= 0.789
# Step 25, Minibatch Loss= 0.4548, Training Accuracy= 0.844
# Step 26, Minibatch Loss= 0.5560, Training Accuracy= 0.742
# Step 27, Minibatch Loss= 0.4555, Training Accuracy= 0.820
# Step 28, Minibatch Loss= 0.5673, Training Accuracy= 0.742
# Step 29, Minibatch Loss= 0.4973, Training Accuracy= 0.781
# Step 30, Minibatch Loss= 0.5296, Training Accuracy= 0.773
# Step 31, Minibatch Loss= 0.5408, Training Accuracy= 0.734
# Step 32, Minibatch Loss= 0.5833, Training Accuracy= 0.672
# Step 33, Minibatch Loss= 0.5801, Training Accuracy= 0.758
# Step 34, Minibatch Loss= 0.4158, Training Accuracy= 0.820
# Step 35, Minibatch Loss= 0.4602, Training Accuracy= 0.797
# Step 36, Minibatch Loss= 0.4649, Training Accuracy= 0.812
# Step 37, Minibatch Loss= 0.4129, Training Accuracy= 0.820
# Step 38, Minibatch Loss= 0.4347, Training Accuracy= 0.836
# Step 39, Minibatch Loss= 0.4958, Training Accuracy= 0.828
# Step 40, Minibatch Loss= 0.3764, Training Accuracy= 0.836
# Step 41, Minibatch Loss= 0.3780, Training Accuracy= 0.859
# Step 42, Minibatch Loss= 0.4566, Training Accuracy= 0.781
# Step 43, Minibatch Loss= 0.4094, Training Accuracy= 0.836
# Step 44, Minibatch Loss= 0.3810, Training Accuracy= 0.820
# Step 45, Minibatch Loss= 0.3860, Training Accuracy= 0.828
# Step 46, Minibatch Loss= 0.4321, Training Accuracy= 0.773
# Step 47, Minibatch Loss= 0.3547, Training Accuracy= 0.836
# Step 48, Minibatch Loss= 0.3414, Training Accuracy= 0.867
# Step 49, Minibatch Loss= 0.3431, Training Accuracy= 0.883
# Step 50, Minibatch Loss= 0.2818, Training Accuracy= 0.875
# Step 51, Minibatch Loss= 0.3142, Training Accuracy= 0.883
# Step 52, Minibatch Loss= 0.2083, Training Accuracy= 0.914
# Step 53, Minibatch Loss= 0.3182, Training Accuracy= 0.891
# Step 54, Minibatch Loss= 0.2663, Training Accuracy= 0.859
# Step 55, Minibatch Loss= 0.2582, Training Accuracy= 0.891
# Step 56, Minibatch Loss= 0.2978, Training Accuracy= 0.859
# Step 57, Minibatch Loss= 0.3817, Training Accuracy= 0.812
# Step 58, Minibatch Loss= 0.2591, Training Accuracy= 0.891
# Step 59, Minibatch Loss= 0.2285, Training Accuracy= 0.891
# Step 60, Minibatch Loss= 0.4051, Training Accuracy= 0.898
# Step 61, Minibatch Loss= 0.2837, Training Accuracy= 0.891
# Step 62, Minibatch Loss= 0.2831, Training Accuracy= 0.875
# Step 63, Minibatch Loss= 0.2183, Training Accuracy= 0.938
# Step 64, Minibatch Loss= 0.3334, Training Accuracy= 0.852
# Step 65, Minibatch Loss= 0.2654, Training Accuracy= 0.922
# Step 66, Minibatch Loss= 0.2741, Training Accuracy= 0.891
# Step 67, Minibatch Loss= 0.2697, Training Accuracy= 0.891
# Step 68, Minibatch Loss= 0.3335, Training Accuracy= 0.852
# Step 69, Minibatch Loss= 0.2761, Training Accuracy= 0.938
# Step 70, Minibatch Loss= 0.3340, Training Accuracy= 0.898
# Step 71, Minibatch Loss= 0.2529, Training Accuracy= 0.906
# Step 72, Minibatch Loss= 0.2056, Training Accuracy= 0.906
# Step 73, Minibatch Loss= 0.1998, Training Accuracy= 0.930
# Step 74, Minibatch Loss= 0.2838, Training Accuracy= 0.875
# Step 75, Minibatch Loss= 0.2975, Training Accuracy= 0.930
# Step 76, Minibatch Loss= 0.1922, Training Accuracy= 0.922
# Step 77, Minibatch Loss= 0.3179, Training Accuracy= 0.898
# Step 78, Minibatch Loss= 0.3705, Training Accuracy= 0.938
# Step 79, Minibatch Loss= 0.2534, Training Accuracy= 0.867
# Step 80, Minibatch Loss= 0.2853, Training Accuracy= 0.906
# Step 81, Minibatch Loss= 0.2811, Training Accuracy= 0.891
# Step 82, Minibatch Loss= 0.2752, Training Accuracy= 0.906
# Step 83, Minibatch Loss= 0.2961, Training Accuracy= 0.875
# Step 84, Minibatch Loss= 0.3103, Training Accuracy= 0.883
# Step 85, Minibatch Loss= 0.2336, Training Accuracy= 0.953
# Step 86, Minibatch Loss= 0.2988, Training Accuracy= 0.922
# Step 87, Minibatch Loss= 0.1286, Training Accuracy= 0.977
# Step 88, Minibatch Loss= 0.2094, Training Accuracy= 0.945
# Step 89, Minibatch Loss= 0.3133, Training Accuracy= 0.883
# Step 90, Minibatch Loss= 0.2820, Training Accuracy= 0.906
# Step 91, Minibatch Loss= 0.2029, Training Accuracy= 0.930
# Step 92, Minibatch Loss= 0.1827, Training Accuracy= 0.914
# Step 93, Minibatch Loss= 0.2094, Training Accuracy= 0.906
# Step 94, Minibatch Loss= 0.1896, Training Accuracy= 0.930
# Step 95, Minibatch Loss= 0.2114, Training Accuracy= 0.945
# Step 96, Minibatch Loss= 0.1333, Training Accuracy= 0.961
# Step 97, Minibatch Loss= 0.1800, Training Accuracy= 0.945
# Step 98, Minibatch Loss= 0.1639, Training Accuracy= 0.961
# Step 99, Minibatch Loss= 0.2951, Training Accuracy= 0.883
# Step 100, Minibatch Loss= 0.1880, Training Accuracy= 0.930
# Step 101, Minibatch Loss= 0.1850, Training Accuracy= 0.938
# Step 102, Minibatch Loss= 0.2184, Training Accuracy= 0.914
# Step 103, Minibatch Loss= 0.2695, Training Accuracy= 0.938
# Step 104, Minibatch Loss= 0.1963, Training Accuracy= 0.945
# Step 105, Minibatch Loss= 0.2276, Training Accuracy= 0.930
# Step 106, Minibatch Loss= 0.2535, Training Accuracy= 0.922
# Step 107, Minibatch Loss= 0.2462, Training Accuracy= 0.906
# Step 108, Minibatch Loss= 0.1767, Training Accuracy= 0.961
# Step 109, Minibatch Loss= 0.2250, Training Accuracy= 0.953
# Step 110, Minibatch Loss= 0.2661, Training Accuracy= 0.914
# Step 111, Minibatch Loss= 0.1805, Training Accuracy= 0.938
# Step 112, Minibatch Loss= 0.2516, Training Accuracy= 0.922
# Step 113, Minibatch Loss= 0.2317, Training Accuracy= 0.914
# Step 114, Minibatch Loss= 0.1405, Training Accuracy= 0.961
# Step 115, Minibatch Loss= 0.2048, Training Accuracy= 0.922
# Step 116, Minibatch Loss= 0.2246, Training Accuracy= 0.898
# Step 117, Minibatch Loss= 0.1812, Training Accuracy= 0.961
# Step 118, Minibatch Loss= 0.1317, Training Accuracy= 0.977
# Step 119, Minibatch Loss= 0.1967, Training Accuracy= 0.953
# Step 120, Minibatch Loss= 0.3111, Training Accuracy= 0.891
# Step 121, Minibatch Loss= 0.2364, Training Accuracy= 0.938
# Step 122, Minibatch Loss= 0.1846, Training Accuracy= 0.945
# Step 123, Minibatch Loss= 0.1341, Training Accuracy= 0.961
# Step 124, Minibatch Loss= 0.1956, Training Accuracy= 0.930
# Step 125, Minibatch Loss= 0.1944, Training Accuracy= 0.914
# Step 126, Minibatch Loss= 0.1794, Training Accuracy= 0.922
# Step 127, Minibatch Loss= 0.1826, Training Accuracy= 0.922
# Step 128, Minibatch Loss= 0.2371, Training Accuracy= 0.922
# Step 129, Minibatch Loss= 0.2046, Training Accuracy= 0.938
# Step 130, Minibatch Loss= 0.1465, Training Accuracy= 0.969
# Step 131, Minibatch Loss= 0.1857, Training Accuracy= 0.930
# Step 132, Minibatch Loss= 0.3084, Training Accuracy= 0.891
# Step 133, Minibatch Loss= 0.2400, Training Accuracy= 0.930
# Step 134, Minibatch Loss= 0.2243, Training Accuracy= 0.945
# Step 135, Minibatch Loss= 0.1353, Training Accuracy= 0.961
# Step 136, Minibatch Loss= 0.1497, Training Accuracy= 0.969
# Step 137, Minibatch Loss= 0.2800, Training Accuracy= 0.922
# Step 138, Minibatch Loss= 0.1536, Training Accuracy= 0.938
# Step 139, Minibatch Loss= 0.1362, Training Accuracy= 0.961
# Step 140, Minibatch Loss= 0.1178, Training Accuracy= 0.969
# Step 141, Minibatch Loss= 0.2391, Training Accuracy= 0.914
# Step 142, Minibatch Loss= 0.1933, Training Accuracy= 0.906
# Step 143, Minibatch Loss= 0.1021, Training Accuracy= 0.969
# Step 144, Minibatch Loss= 0.1841, Training Accuracy= 0.930
# Step 145, Minibatch Loss= 0.1108, Training Accuracy= 0.945
# Step 146, Minibatch Loss= 0.1779, Training Accuracy= 0.930
# Step 147, Minibatch Loss= 0.2309, Training Accuracy= 0.898
# Step 148, Minibatch Loss= 0.2069, Training Accuracy= 0.938
# Step 149, Minibatch Loss= 0.1545, Training Accuracy= 0.953
# Step 150, Minibatch Loss= 0.1409, Training Accuracy= 0.953
# Step 151, Minibatch Loss= 0.2346, Training Accuracy= 0.945
# Step 152, Minibatch Loss= 0.2183, Training Accuracy= 0.922
# Step 153, Minibatch Loss= 0.2196, Training Accuracy= 0.922
# Step 154, Minibatch Loss= 0.1428, Training Accuracy= 0.969
# Step 155, Minibatch Loss= 0.1616, Training Accuracy= 0.953
# Step 156, Minibatch Loss= 0.1933, Training Accuracy= 0.898
# Step 157, Minibatch Loss= 0.2109, Training Accuracy= 0.953
# Step 158, Minibatch Loss= 0.1235, Training Accuracy= 0.984
# Step 159, Minibatch Loss= 0.2312, Training Accuracy= 0.906
# Step 160, Minibatch Loss= 0.2852, Training Accuracy= 0.938
# Step 161, Minibatch Loss= 0.1834, Training Accuracy= 0.922
# Step 162, Minibatch Loss= 0.2154, Training Accuracy= 0.930
# Step 163, Minibatch Loss= 0.2060, Training Accuracy= 0.938
# Step 164, Minibatch Loss= 0.1738, Training Accuracy= 0.945
# Step 165, Minibatch Loss= 0.1865, Training Accuracy= 0.938
# Step 166, Minibatch Loss= 0.2803, Training Accuracy= 0.883
# Step 167, Minibatch Loss= 0.0999, Training Accuracy= 0.977
# Step 168, Minibatch Loss= 0.2215, Training Accuracy= 0.945
# Step 169, Minibatch Loss= 0.1638, Training Accuracy= 0.945
# Step 170, Minibatch Loss= 0.1573, Training Accuracy= 0.953
# Step 171, Minibatch Loss= 0.2054, Training Accuracy= 0.914
# Step 172, Minibatch Loss= 0.2077, Training Accuracy= 0.922
# Step 173, Minibatch Loss= 0.1673, Training Accuracy= 0.945
# Step 174, Minibatch Loss= 0.1831, Training Accuracy= 0.914
# Step 175, Minibatch Loss= 0.2308, Training Accuracy= 0.930
# Step 176, Minibatch Loss= 0.1940, Training Accuracy= 0.953
# Step 177, Minibatch Loss= 0.1977, Training Accuracy= 0.945
# Step 178, Minibatch Loss= 0.1226, Training Accuracy= 0.977
# Step 179, Minibatch Loss= 0.1389, Training Accuracy= 0.953
# Step 180, Minibatch Loss= 0.2066, Training Accuracy= 0.938
# Step 181, Minibatch Loss= 0.1749, Training Accuracy= 0.938
# Step 182, Minibatch Loss= 0.1446, Training Accuracy= 0.938
# Step 183, Minibatch Loss= 0.2425, Training Accuracy= 0.867
# Step 184, Minibatch Loss= 0.1793, Training Accuracy= 0.914
# Step 185, Minibatch Loss= 0.1159, Training Accuracy= 0.961
# Step 186, Minibatch Loss= 0.3248, Training Accuracy= 0.914
# Step 187, Minibatch Loss= 0.2009, Training Accuracy= 0.938
# Step 188, Minibatch Loss= 0.1852, Training Accuracy= 0.945
# Step 189, Minibatch Loss= 0.1428, Training Accuracy= 0.953
# Step 190, Minibatch Loss= 0.2311, Training Accuracy= 0.922
# Step 191, Minibatch Loss= 0.1955, Training Accuracy= 0.945
# Step 192, Minibatch Loss= 0.2008, Training Accuracy= 0.906
# Step 193, Minibatch Loss= 0.1380, Training Accuracy= 0.938
# Step 194, Minibatch Loss= 0.1973, Training Accuracy= 0.914
# Step 195, Minibatch Loss= 0.1657, Training Accuracy= 0.953
# Step 196, Minibatch Loss= 0.2290, Training Accuracy= 0.930
# Step 197, Minibatch Loss= 0.0893, Training Accuracy= 0.977
# Step 198, Minibatch Loss= 0.0977, Training Accuracy= 0.977
# Step 199, Minibatch Loss= 0.2432, Training Accuracy= 0.938
# Step 200, Minibatch Loss= 0.2219, Training Accuracy= 0.914
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node input_producer_1/input_producer/input_producer_EnqueueMany}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node input_producer/input_producer/input_producer_EnqueueMany}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
# Exception in thread QueueRunnerThread-batch_1/fifo_queue-batch_1/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
# Exception in thread QueueRunnerThread-input_producer_1/input_producer-input_producer_1/input_producer/input_producer_EnqueueMany:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node input_producer_1/input_producer/input_producer_EnqueueMany}}]]
# Exception in thread QueueRunnerThread-batch_1/fifo_queue-batch_1/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
#
# Exception in thread QueueRunnerThread-input_producer/input_producer-input_producer/input_producer/input_producer_EnqueueMany:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node input_producer/input_producer/input_producer_EnqueueMany}}]]
#
#
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
#
# Exception in thread QueueRunnerThread-batch_1/fifo_queue-batch_1/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
#
# Exception in thread QueueRunnerThread-batch_1/fifo_queue-batch_1/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch_1/fifo_queue_enqueue}}]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b0efb8fa2305> in <module>()
#      49
#      50
# ---> 51     for step in range(1, (trainSize/batchSize )+1):
#      52         # Run optimization and calculate batch loss and accuracy
#      53         acc3 = sess.run(accuracy)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
test_accuracy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8e2f80af63c6> in <module>()
# ----> 1 test_accuracy
#
# NameError: name 'test_accuracy' is not defined

# %%
train_acc
# Out:
# 0

# %%
#LEFT OFF AT PIPE THE DATASET TO A MODEL
#NEED TO:
#    SEPERATE DATA INTO TRAINING AND TESTING ###DONE
#    TRAIN MODEL
#    TEST MODEL
