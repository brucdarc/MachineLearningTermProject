# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
tf.enable_eager_execution()
tf.VERSION
# Out:
# '1.13.1'

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
DATASET_PATH = read_images('/s/bach/g/under/cutreap/Desktop/cs445/cell_images/', 'folder', 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd5cc5ed4d22> in <module>()
# ----> 1 DATASET_PATH = read_images('/s/bach/g/under/cutreap/Desktop/cs445/cell_images/', 'folder', 1)
#
# NameError: name 'read_images' is not defined

# %%
from __future__ import print_function

import tensorflow as tf
from tensorflow import keras
import os

# Dataset Parameters - CHANGE HERE
MODE = 'folder' # or 'file', if you choose a plain text file (see above).
DATASET_PATH = '/path/to/dataset/' # the dataset file or root folder path.

# Image Parameters
N_CLASSES = 2 # CHANGE HERE, total number of classes
IMG_HEIGHT = 128 # CHANGE HERE, the image height to be resized to
IMG_WIDTH = 128 # CHANGE HERE, the image width to be resized to
CHANNELS = 3 # The 3 color channels, change to 1 if grayscale

# %%
learning_rate = 0.001
num_steps = 500
batch_size = 128
display_step = 1

# Network Parameters
dropout = 0.75 # Dropout, probability to keep units

# Build the data input
X, Y = read_images('/s/bach/g/under/cutreap/Desktop/cs445/cell_images/', 'folder', 200)

# %%
Y.dtype
# Out:
# tf.int32

# %%
X
# Out:
# <tf.Tensor 'batch:0' shape=(200, 128, 128, 3) dtype=float32>

# %%
logits_train = conv_net(X, N_CLASSES, dropout, reuse=False, is_training=True)
# Create another graph for testing that reuse the same weights
logits_test = conv_net(X, N_CLASSES, dropout, reuse=True, is_training=False)

# Define loss and optimizer (with train logits, for dropout to take effect)
loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
    logits=logits_train, labels=Y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(logits_test, 1), tf.cast(Y, tf.int64))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Saver object
saver = tf.train.Saver()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    # Start the data queue
    tf.train.start_queue_runners()

    # Training cycle
    for step in range(1, num_steps+1):

        if step % display_step == 0:
            # Run optimization and calculate batch loss and accuracy
            _, loss, acc = sess.run([train_op, loss_op, accuracy])
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))
        else:
            # Only run the optimization op (backprop)
            sess.run(train_op)

    print("Optimization Finished!")
    # Save your model
    saver.save(sess, 'my_tf_model4')
# Out:
# WARNING:tensorflow:From <ipython-input-1-729192468e34>:8: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-1-729192468e34>:10: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-1-729192468e34>:24: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-7-7369b9677710>:28: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Step 1, Minibatch Loss= 0.6877, Training Accuracy= 0.555
# Step 2, Minibatch Loss= 2.7328, Training Accuracy= 0.520
# Step 3, Minibatch Loss= 0.9233, Training Accuracy= 0.520
# Step 4, Minibatch Loss= 0.8726, Training Accuracy= 0.445
# Step 5, Minibatch Loss= 0.6484, Training Accuracy= 0.530
# Step 6, Minibatch Loss= 0.7783, Training Accuracy= 0.520
# Step 7, Minibatch Loss= 0.6533, Training Accuracy= 0.565
# Step 8, Minibatch Loss= 0.6233, Training Accuracy= 0.685
# Step 9, Minibatch Loss= 0.6281, Training Accuracy= 0.655
# Step 10, Minibatch Loss= 0.6338, Training Accuracy= 0.645
# Step 11, Minibatch Loss= 0.6130, Training Accuracy= 0.695
# Step 12, Minibatch Loss= 0.6131, Training Accuracy= 0.715
# Step 13, Minibatch Loss= 0.6154, Training Accuracy= 0.725
# Step 14, Minibatch Loss= 0.5443, Training Accuracy= 0.760
# Step 15, Minibatch Loss= 0.5830, Training Accuracy= 0.730
# Step 16, Minibatch Loss= 0.5696, Training Accuracy= 0.730
# Step 17, Minibatch Loss= 0.5772, Training Accuracy= 0.700
# Step 18, Minibatch Loss= 0.5168, Training Accuracy= 0.710
# Step 19, Minibatch Loss= 0.4963, Training Accuracy= 0.785
# Step 20, Minibatch Loss= 0.5687, Training Accuracy= 0.725
# Step 21, Minibatch Loss= 0.5206, Training Accuracy= 0.815
# Step 22, Minibatch Loss= 0.5054, Training Accuracy= 0.805
# Step 23, Minibatch Loss= 0.5129, Training Accuracy= 0.750
# Step 24, Minibatch Loss= 0.4553, Training Accuracy= 0.795
# Step 25, Minibatch Loss= 0.4957, Training Accuracy= 0.765
# Step 26, Minibatch Loss= 0.5107, Training Accuracy= 0.790
# Step 27, Minibatch Loss= 0.4480, Training Accuracy= 0.820
# Step 28, Minibatch Loss= 0.4623, Training Accuracy= 0.830
# Step 29, Minibatch Loss= 0.4822, Training Accuracy= 0.775
# Step 30, Minibatch Loss= 0.4898, Training Accuracy= 0.750
# Step 31, Minibatch Loss= 0.4754, Training Accuracy= 0.750
# Step 32, Minibatch Loss= 0.4345, Training Accuracy= 0.805
# Step 33, Minibatch Loss= 0.4393, Training Accuracy= 0.790
# Step 34, Minibatch Loss= 0.4871, Training Accuracy= 0.795
# Step 35, Minibatch Loss= 0.4441, Training Accuracy= 0.805
# Step 36, Minibatch Loss= 0.3995, Training Accuracy= 0.815
# Step 37, Minibatch Loss= 0.4088, Training Accuracy= 0.780
# Step 38, Minibatch Loss= 0.3315, Training Accuracy= 0.865
# Step 39, Minibatch Loss= 0.3235, Training Accuracy= 0.875
# Step 40, Minibatch Loss= 0.4041, Training Accuracy= 0.835
# Step 41, Minibatch Loss= 0.3824, Training Accuracy= 0.880
# Step 42, Minibatch Loss= 0.2923, Training Accuracy= 0.880
# Step 43, Minibatch Loss= 0.3128, Training Accuracy= 0.870
# Step 44, Minibatch Loss= 0.3014, Training Accuracy= 0.890
# Step 45, Minibatch Loss= 0.3486, Training Accuracy= 0.820
# Step 46, Minibatch Loss= 0.2769, Training Accuracy= 0.835
# Step 47, Minibatch Loss= 0.2980, Training Accuracy= 0.885
# Step 48, Minibatch Loss= 0.3214, Training Accuracy= 0.855
# Step 49, Minibatch Loss= 0.2869, Training Accuracy= 0.865
# Step 50, Minibatch Loss= 0.2925, Training Accuracy= 0.880
# Step 51, Minibatch Loss= 0.2781, Training Accuracy= 0.885
# Step 52, Minibatch Loss= 0.3768, Training Accuracy= 0.860
# Step 53, Minibatch Loss= 0.2953, Training Accuracy= 0.905
# Step 54, Minibatch Loss= 0.2442, Training Accuracy= 0.915
# Step 55, Minibatch Loss= 0.2723, Training Accuracy= 0.855
# Step 56, Minibatch Loss= 0.3393, Training Accuracy= 0.860
# Step 57, Minibatch Loss= 0.2032, Training Accuracy= 0.930
# Step 58, Minibatch Loss= 0.3022, Training Accuracy= 0.910
# Step 59, Minibatch Loss= 0.4363, Training Accuracy= 0.895
# Step 60, Minibatch Loss= 0.4440, Training Accuracy= 0.885
# Step 61, Minibatch Loss= 0.2357, Training Accuracy= 0.905
# Step 62, Minibatch Loss= 0.3217, Training Accuracy= 0.865
# Step 63, Minibatch Loss= 0.3106, Training Accuracy= 0.885
# Step 64, Minibatch Loss= 0.2980, Training Accuracy= 0.860
# Step 65, Minibatch Loss= 0.3196, Training Accuracy= 0.870
# Step 66, Minibatch Loss= 0.2123, Training Accuracy= 0.940
# Step 67, Minibatch Loss= 0.3105, Training Accuracy= 0.895
# Step 68, Minibatch Loss= 0.2927, Training Accuracy= 0.920
# Step 69, Minibatch Loss= 0.3304, Training Accuracy= 0.915
# Step 70, Minibatch Loss= 0.2351, Training Accuracy= 0.950
# Step 71, Minibatch Loss= 0.2110, Training Accuracy= 0.910
# Step 72, Minibatch Loss= 0.2502, Training Accuracy= 0.905
# Step 73, Minibatch Loss= 0.2232, Training Accuracy= 0.915
# Step 74, Minibatch Loss= 0.1465, Training Accuracy= 0.950
# Step 75, Minibatch Loss= 0.2271, Training Accuracy= 0.930
# Step 76, Minibatch Loss= 0.2896, Training Accuracy= 0.890
# Step 77, Minibatch Loss= 0.2150, Training Accuracy= 0.900
# Step 78, Minibatch Loss= 0.2409, Training Accuracy= 0.905
# Step 79, Minibatch Loss= 0.2004, Training Accuracy= 0.930
# Step 80, Minibatch Loss= 0.2662, Training Accuracy= 0.910
# Step 81, Minibatch Loss= 0.1915, Training Accuracy= 0.930
# Step 82, Minibatch Loss= 0.2462, Training Accuracy= 0.940
# Step 83, Minibatch Loss= 0.2137, Training Accuracy= 0.920
# Step 84, Minibatch Loss= 0.2541, Training Accuracy= 0.915
# Step 85, Minibatch Loss= 0.1621, Training Accuracy= 0.955
# Step 86, Minibatch Loss= 0.2290, Training Accuracy= 0.905
# Step 87, Minibatch Loss= 0.1896, Training Accuracy= 0.905
# Step 88, Minibatch Loss= 0.2841, Training Accuracy= 0.890
# Step 89, Minibatch Loss= 0.2212, Training Accuracy= 0.910
# Step 90, Minibatch Loss= 0.1949, Training Accuracy= 0.945
# Step 91, Minibatch Loss= 0.1320, Training Accuracy= 0.970
# Step 92, Minibatch Loss= 0.2090, Training Accuracy= 0.935
# Step 93, Minibatch Loss= 0.2596, Training Accuracy= 0.900
# Step 94, Minibatch Loss= 0.1230, Training Accuracy= 0.965
# Step 95, Minibatch Loss= 0.1574, Training Accuracy= 0.925
# Step 96, Minibatch Loss= 0.2256, Training Accuracy= 0.920
# Step 97, Minibatch Loss= 0.1403, Training Accuracy= 0.945
# Step 98, Minibatch Loss= 0.1901, Training Accuracy= 0.935
# Step 99, Minibatch Loss= 0.1713, Training Accuracy= 0.945
# Step 100, Minibatch Loss= 0.1085, Training Accuracy= 0.965
# Step 101, Minibatch Loss= 0.1425, Training Accuracy= 0.965
# Step 102, Minibatch Loss= 0.2205, Training Accuracy= 0.910
# Step 103, Minibatch Loss= 0.1803, Training Accuracy= 0.920
# Step 104, Minibatch Loss= 0.1827, Training Accuracy= 0.930
# Step 105, Minibatch Loss= 0.1602, Training Accuracy= 0.950
# Step 106, Minibatch Loss= 0.1599, Training Accuracy= 0.960
# Step 107, Minibatch Loss= 0.1452, Training Accuracy= 0.950
# Step 108, Minibatch Loss= 0.1601, Training Accuracy= 0.950
# Step 109, Minibatch Loss= 0.1288, Training Accuracy= 0.965
# Step 110, Minibatch Loss= 0.1883, Training Accuracy= 0.925
# Step 111, Minibatch Loss= 0.1826, Training Accuracy= 0.955
# Step 112, Minibatch Loss= 0.2332, Training Accuracy= 0.935
# Step 113, Minibatch Loss= 0.2811, Training Accuracy= 0.905
# Step 114, Minibatch Loss= 0.1286, Training Accuracy= 0.965
# Step 115, Minibatch Loss= 0.1259, Training Accuracy= 0.960
# Step 116, Minibatch Loss= 0.1819, Training Accuracy= 0.965
# Step 117, Minibatch Loss= 0.2108, Training Accuracy= 0.920
# Step 118, Minibatch Loss= 0.1572, Training Accuracy= 0.935
# Step 119, Minibatch Loss= 0.2837, Training Accuracy= 0.915
# Step 120, Minibatch Loss= 0.1318, Training Accuracy= 0.955
# Step 121, Minibatch Loss= 0.2198, Training Accuracy= 0.960
# Step 122, Minibatch Loss= 0.2023, Training Accuracy= 0.925
# Step 123, Minibatch Loss= 0.2406, Training Accuracy= 0.905
# Step 124, Minibatch Loss= 0.1822, Training Accuracy= 0.930
# Step 125, Minibatch Loss= 0.1985, Training Accuracy= 0.930
# Step 126, Minibatch Loss= 0.1239, Training Accuracy= 0.960
# Step 127, Minibatch Loss= 0.1621, Training Accuracy= 0.950
# Step 128, Minibatch Loss= 0.1414, Training Accuracy= 0.945
# Step 129, Minibatch Loss= 0.1424, Training Accuracy= 0.950
# Step 130, Minibatch Loss= 0.1667, Training Accuracy= 0.925
# Step 131, Minibatch Loss= 0.1959, Training Accuracy= 0.925
# Step 132, Minibatch Loss= 0.1647, Training Accuracy= 0.935
# Step 133, Minibatch Loss= 0.2078, Training Accuracy= 0.915
# Step 134, Minibatch Loss= 0.1488, Training Accuracy= 0.960
# Step 135, Minibatch Loss= 0.2384, Training Accuracy= 0.945
# Step 136, Minibatch Loss= 0.1502, Training Accuracy= 0.960
# Step 137, Minibatch Loss= 0.2132, Training Accuracy= 0.915
# Step 138, Minibatch Loss= 0.1429, Training Accuracy= 0.950
# Step 139, Minibatch Loss= 0.2269, Training Accuracy= 0.925
# Step 140, Minibatch Loss= 0.2008, Training Accuracy= 0.905
# Step 141, Minibatch Loss= 0.1828, Training Accuracy= 0.945
# Step 142, Minibatch Loss= 0.1002, Training Accuracy= 0.980
# Step 143, Minibatch Loss= 0.2204, Training Accuracy= 0.930
# Step 144, Minibatch Loss= 0.1905, Training Accuracy= 0.940
# Step 145, Minibatch Loss= 0.1403, Training Accuracy= 0.945
# Step 146, Minibatch Loss= 0.1627, Training Accuracy= 0.925
# Step 147, Minibatch Loss= 0.1695, Training Accuracy= 0.940
# Step 148, Minibatch Loss= 0.1100, Training Accuracy= 0.955
# Step 149, Minibatch Loss= 0.1702, Training Accuracy= 0.920
# Step 150, Minibatch Loss= 0.2121, Training Accuracy= 0.955
# Step 151, Minibatch Loss= 0.1431, Training Accuracy= 0.945
# Step 152, Minibatch Loss= 0.1594, Training Accuracy= 0.950
# Step 153, Minibatch Loss= 0.1825, Training Accuracy= 0.945
# Step 154, Minibatch Loss= 0.1869, Training Accuracy= 0.940
# Step 155, Minibatch Loss= 0.1658, Training Accuracy= 0.950
# Step 156, Minibatch Loss= 0.2434, Training Accuracy= 0.915
# Step 157, Minibatch Loss= 0.1586, Training Accuracy= 0.950
# Step 158, Minibatch Loss= 0.1305, Training Accuracy= 0.955
# Step 159, Minibatch Loss= 0.1697, Training Accuracy= 0.945
# Step 160, Minibatch Loss= 0.1315, Training Accuracy= 0.960
# Step 161, Minibatch Loss= 0.1950, Training Accuracy= 0.935
# Step 162, Minibatch Loss= 0.1864, Training Accuracy= 0.945
# Step 163, Minibatch Loss= 0.2636, Training Accuracy= 0.905
# Step 164, Minibatch Loss= 0.1839, Training Accuracy= 0.935
# Step 165, Minibatch Loss= 0.2390, Training Accuracy= 0.910
# Step 166, Minibatch Loss= 0.2120, Training Accuracy= 0.910
# Step 167, Minibatch Loss= 0.2536, Training Accuracy= 0.910
# Step 168, Minibatch Loss= 0.1216, Training Accuracy= 0.960
# Step 169, Minibatch Loss= 0.1872, Training Accuracy= 0.940
# Step 170, Minibatch Loss= 0.1659, Training Accuracy= 0.955
# Step 171, Minibatch Loss= 0.1990, Training Accuracy= 0.930
# Step 172, Minibatch Loss= 0.2193, Training Accuracy= 0.945
# Step 173, Minibatch Loss= 0.1166, Training Accuracy= 0.970
# Step 174, Minibatch Loss= 0.2227, Training Accuracy= 0.925
# Step 175, Minibatch Loss= 0.1222, Training Accuracy= 0.960
# Step 176, Minibatch Loss= 0.1574, Training Accuracy= 0.930
# Step 177, Minibatch Loss= 0.2695, Training Accuracy= 0.910
# Step 178, Minibatch Loss= 0.1001, Training Accuracy= 0.965
# Step 179, Minibatch Loss= 0.1951, Training Accuracy= 0.950
# Step 180, Minibatch Loss= 0.2039, Training Accuracy= 0.945
# Step 181, Minibatch Loss= 0.1219, Training Accuracy= 0.970
# Step 182, Minibatch Loss= 0.2239, Training Accuracy= 0.925
# Step 183, Minibatch Loss= 0.1729, Training Accuracy= 0.950
# Step 184, Minibatch Loss= 0.2442, Training Accuracy= 0.935
# Step 185, Minibatch Loss= 0.1242, Training Accuracy= 0.960
# Step 186, Minibatch Loss= 0.1642, Training Accuracy= 0.945
# Step 187, Minibatch Loss= 0.1140, Training Accuracy= 0.960
# Step 188, Minibatch Loss= 0.1186, Training Accuracy= 0.955
# Step 189, Minibatch Loss= 0.2041, Training Accuracy= 0.925
# Step 190, Minibatch Loss= 0.1499, Training Accuracy= 0.940
# Step 191, Minibatch Loss= 0.1325, Training Accuracy= 0.975
# Step 192, Minibatch Loss= 0.1129, Training Accuracy= 0.970
# Step 193, Minibatch Loss= 0.2203, Training Accuracy= 0.930
# Step 194, Minibatch Loss= 0.1599, Training Accuracy= 0.960
# Step 195, Minibatch Loss= 0.1536, Training Accuracy= 0.950
# Step 196, Minibatch Loss= 0.2231, Training Accuracy= 0.910
# Step 197, Minibatch Loss= 0.1854, Training Accuracy= 0.930
# Step 198, Minibatch Loss= 0.1933, Training Accuracy= 0.945
# Step 199, Minibatch Loss= 0.1024, Training Accuracy= 0.960
# Step 200, Minibatch Loss= 0.1235, Training Accuracy= 0.960
# Step 201, Minibatch Loss= 0.2498, Training Accuracy= 0.920
# Step 202, Minibatch Loss= 0.1644, Training Accuracy= 0.940
# Step 203, Minibatch Loss= 0.1716, Training Accuracy= 0.940
# Step 204, Minibatch Loss= 0.1311, Training Accuracy= 0.970
# Step 205, Minibatch Loss= 0.1541, Training Accuracy= 0.970
# Step 206, Minibatch Loss= 0.1855, Training Accuracy= 0.935
# Step 207, Minibatch Loss= 0.1336, Training Accuracy= 0.960
# Step 208, Minibatch Loss= 0.1310, Training Accuracy= 0.935
# Step 209, Minibatch Loss= 0.1381, Training Accuracy= 0.960
# Step 210, Minibatch Loss= 0.1702, Training Accuracy= 0.940
# Step 211, Minibatch Loss= 0.0894, Training Accuracy= 0.955
# Step 212, Minibatch Loss= 0.2004, Training Accuracy= 0.940
# Step 213, Minibatch Loss= 0.1899, Training Accuracy= 0.925
# Step 214, Minibatch Loss= 0.2136, Training Accuracy= 0.945
# Step 215, Minibatch Loss= 0.1085, Training Accuracy= 0.970
# Step 216, Minibatch Loss= 0.1903, Training Accuracy= 0.935
# Step 217, Minibatch Loss= 0.2010, Training Accuracy= 0.935
# Step 218, Minibatch Loss= 0.2295, Training Accuracy= 0.940
# Step 219, Minibatch Loss= 0.1725, Training Accuracy= 0.950
# Step 220, Minibatch Loss= 0.1266, Training Accuracy= 0.965
# Step 221, Minibatch Loss= 0.1737, Training Accuracy= 0.950
# Step 222, Minibatch Loss= 0.1806, Training Accuracy= 0.950
# Step 223, Minibatch Loss= 0.1123, Training Accuracy= 0.965
# Step 224, Minibatch Loss= 0.1317, Training Accuracy= 0.950
# Step 225, Minibatch Loss= 0.2026, Training Accuracy= 0.915
# Step 226, Minibatch Loss= 0.0690, Training Accuracy= 0.990
# Step 227, Minibatch Loss= 0.1215, Training Accuracy= 0.960
# Step 228, Minibatch Loss= 0.1626, Training Accuracy= 0.950
# Step 229, Minibatch Loss= 0.1746, Training Accuracy= 0.955
# Step 230, Minibatch Loss= 0.1056, Training Accuracy= 0.960
# Step 231, Minibatch Loss= 0.1055, Training Accuracy= 0.965
# Step 232, Minibatch Loss= 0.1705, Training Accuracy= 0.965
# Step 233, Minibatch Loss= 0.1465, Training Accuracy= 0.950
# Step 234, Minibatch Loss= 0.1652, Training Accuracy= 0.935
# Step 235, Minibatch Loss= 0.1046, Training Accuracy= 0.970
# Step 236, Minibatch Loss= 0.1690, Training Accuracy= 0.945
# Step 237, Minibatch Loss= 0.2265, Training Accuracy= 0.900
# Step 238, Minibatch Loss= 0.1430, Training Accuracy= 0.945
# Step 239, Minibatch Loss= 0.2135, Training Accuracy= 0.905
# Step 240, Minibatch Loss= 0.1331, Training Accuracy= 0.955
# Step 241, Minibatch Loss= 0.1242, Training Accuracy= 0.965
# Step 242, Minibatch Loss= 0.1970, Training Accuracy= 0.950
# Step 243, Minibatch Loss= 0.1458, Training Accuracy= 0.945
# Step 244, Minibatch Loss= 0.1842, Training Accuracy= 0.955
# Step 245, Minibatch Loss= 0.1030, Training Accuracy= 0.960
# Step 246, Minibatch Loss= 0.1048, Training Accuracy= 0.970
# Step 247, Minibatch Loss= 0.1319, Training Accuracy= 0.950
# Step 248, Minibatch Loss= 0.2252, Training Accuracy= 0.915
# Step 249, Minibatch Loss= 0.2232, Training Accuracy= 0.920
# Step 250, Minibatch Loss= 0.2216, Training Accuracy= 0.920
# Step 251, Minibatch Loss= 0.1106, Training Accuracy= 0.960
# Step 252, Minibatch Loss= 0.2281, Training Accuracy= 0.925
# Step 253, Minibatch Loss= 0.1793, Training Accuracy= 0.935
# Step 254, Minibatch Loss= 0.1838, Training Accuracy= 0.940
# Step 255, Minibatch Loss= 0.1288, Training Accuracy= 0.965
# Step 256, Minibatch Loss= 0.2245, Training Accuracy= 0.930
# Step 257, Minibatch Loss= 0.2015, Training Accuracy= 0.930
# Step 258, Minibatch Loss= 0.1703, Training Accuracy= 0.940
# Step 259, Minibatch Loss= 0.2053, Training Accuracy= 0.935
# Step 260, Minibatch Loss= 0.1941, Training Accuracy= 0.910
# Step 261, Minibatch Loss= 0.1671, Training Accuracy= 0.940
# Step 262, Minibatch Loss= 0.2845, Training Accuracy= 0.940
# Step 263, Minibatch Loss= 0.2726, Training Accuracy= 0.920
# Step 264, Minibatch Loss= 0.1427, Training Accuracy= 0.960
# Step 265, Minibatch Loss= 0.1546, Training Accuracy= 0.950
# Step 266, Minibatch Loss= 0.1831, Training Accuracy= 0.930
# Step 267, Minibatch Loss= 0.1049, Training Accuracy= 0.955
# Step 268, Minibatch Loss= 0.1854, Training Accuracy= 0.940
# Step 269, Minibatch Loss= 0.0771, Training Accuracy= 0.970
# Step 270, Minibatch Loss= 0.1982, Training Accuracy= 0.965
# Step 271, Minibatch Loss= 0.1906, Training Accuracy= 0.940
# Step 272, Minibatch Loss= 0.1876, Training Accuracy= 0.945
# Step 273, Minibatch Loss= 0.1286, Training Accuracy= 0.945
# Step 274, Minibatch Loss= 0.1634, Training Accuracy= 0.935
# Step 275, Minibatch Loss= 0.1509, Training Accuracy= 0.960
# Step 276, Minibatch Loss= 0.0908, Training Accuracy= 0.975
# Step 277, Minibatch Loss= 0.2086, Training Accuracy= 0.945
# Step 278, Minibatch Loss= 0.2189, Training Accuracy= 0.930
# Step 279, Minibatch Loss= 0.0603, Training Accuracy= 0.990
# Step 280, Minibatch Loss= 0.1463, Training Accuracy= 0.950
# Step 281, Minibatch Loss= 0.1833, Training Accuracy= 0.935
# Step 282, Minibatch Loss= 0.1655, Training Accuracy= 0.950
# Step 283, Minibatch Loss= 0.1097, Training Accuracy= 0.975
# Step 284, Minibatch Loss= 0.1690, Training Accuracy= 0.950
# Step 285, Minibatch Loss= 0.1273, Training Accuracy= 0.945
# Step 286, Minibatch Loss= 0.0959, Training Accuracy= 0.965
# Step 287, Minibatch Loss= 0.1296, Training Accuracy= 0.965
# Step 288, Minibatch Loss= 0.1819, Training Accuracy= 0.935
# Step 289, Minibatch Loss= 0.0902, Training Accuracy= 0.960
# Step 290, Minibatch Loss= 0.2461, Training Accuracy= 0.935
# Step 291, Minibatch Loss= 0.2150, Training Accuracy= 0.950
# Step 292, Minibatch Loss= 0.1016, Training Accuracy= 0.965
# Step 293, Minibatch Loss= 0.2176, Training Accuracy= 0.940
# Step 294, Minibatch Loss= 0.1771, Training Accuracy= 0.920
# Step 295, Minibatch Loss= 0.1018, Training Accuracy= 0.965
# Step 296, Minibatch Loss= 0.1480, Training Accuracy= 0.935
# Step 297, Minibatch Loss= 0.1825, Training Accuracy= 0.935
# Step 298, Minibatch Loss= 0.1373, Training Accuracy= 0.950
# Step 299, Minibatch Loss= 0.1546, Training Accuracy= 0.950
# Step 300, Minibatch Loss= 0.1630, Training Accuracy= 0.945
# Step 301, Minibatch Loss= 0.1666, Training Accuracy= 0.930
# Step 302, Minibatch Loss= 0.0994, Training Accuracy= 0.960
# Step 303, Minibatch Loss= 0.1552, Training Accuracy= 0.955
# Step 304, Minibatch Loss= 0.0750, Training Accuracy= 0.990
# Step 305, Minibatch Loss= 0.2017, Training Accuracy= 0.940
# Step 306, Minibatch Loss= 0.1609, Training Accuracy= 0.950
# Step 307, Minibatch Loss= 0.1314, Training Accuracy= 0.960
# Step 308, Minibatch Loss= 0.1346, Training Accuracy= 0.955
# Step 309, Minibatch Loss= 0.0749, Training Accuracy= 0.980
# Step 310, Minibatch Loss= 0.1919, Training Accuracy= 0.935
# Step 311, Minibatch Loss= 0.1553, Training Accuracy= 0.940
# Step 312, Minibatch Loss= 0.2321, Training Accuracy= 0.925
# Step 313, Minibatch Loss= 0.1568, Training Accuracy= 0.940
# Step 314, Minibatch Loss= 0.1902, Training Accuracy= 0.945
# Step 315, Minibatch Loss= 0.2550, Training Accuracy= 0.920
# Step 316, Minibatch Loss= 0.1468, Training Accuracy= 0.940
# Step 317, Minibatch Loss= 0.1210, Training Accuracy= 0.960
# Step 318, Minibatch Loss= 0.1571, Training Accuracy= 0.940
# Step 319, Minibatch Loss= 0.1118, Training Accuracy= 0.965
# Step 320, Minibatch Loss= 0.0960, Training Accuracy= 0.970
# Step 321, Minibatch Loss= 0.1061, Training Accuracy= 0.965
# Step 322, Minibatch Loss= 0.1201, Training Accuracy= 0.970
# Step 323, Minibatch Loss= 0.1925, Training Accuracy= 0.965
# Step 324, Minibatch Loss= 0.1454, Training Accuracy= 0.935
# Step 325, Minibatch Loss= 0.1278, Training Accuracy= 0.960
# Step 326, Minibatch Loss= 0.1988, Training Accuracy= 0.930
# Step 327, Minibatch Loss= 0.1579, Training Accuracy= 0.940
# Step 328, Minibatch Loss= 0.2617, Training Accuracy= 0.915
# Step 329, Minibatch Loss= 0.0986, Training Accuracy= 0.955
# Step 330, Minibatch Loss= 0.1310, Training Accuracy= 0.965
# Step 331, Minibatch Loss= 0.1576, Training Accuracy= 0.930
# Step 332, Minibatch Loss= 0.1344, Training Accuracy= 0.960
# Step 333, Minibatch Loss= 0.1390, Training Accuracy= 0.945
# Step 334, Minibatch Loss= 0.1184, Training Accuracy= 0.950
# Step 335, Minibatch Loss= 0.1344, Training Accuracy= 0.965
# Step 336, Minibatch Loss= 0.1017, Training Accuracy= 0.960
# Step 337, Minibatch Loss= 0.1692, Training Accuracy= 0.950
# Step 338, Minibatch Loss= 0.1913, Training Accuracy= 0.940
# Step 339, Minibatch Loss= 0.1121, Training Accuracy= 0.970
# Step 340, Minibatch Loss= 0.1055, Training Accuracy= 0.965
# Step 341, Minibatch Loss= 0.1803, Training Accuracy= 0.935
# Step 342, Minibatch Loss= 0.2114, Training Accuracy= 0.955
# Step 343, Minibatch Loss= 0.0579, Training Accuracy= 0.990
# Step 344, Minibatch Loss= 0.1325, Training Accuracy= 0.950
# Step 345, Minibatch Loss= 0.1664, Training Accuracy= 0.960
# Step 346, Minibatch Loss= 0.1454, Training Accuracy= 0.945
# Step 347, Minibatch Loss= 0.2349, Training Accuracy= 0.925
# Step 348, Minibatch Loss= 0.1291, Training Accuracy= 0.955
# Step 349, Minibatch Loss= 0.1272, Training Accuracy= 0.950
# Step 350, Minibatch Loss= 0.0868, Training Accuracy= 0.965
# Step 351, Minibatch Loss= 0.0944, Training Accuracy= 0.980
# Step 352, Minibatch Loss= 0.1841, Training Accuracy= 0.965
# Step 353, Minibatch Loss= 0.1327, Training Accuracy= 0.955
# Step 354, Minibatch Loss= 0.1798, Training Accuracy= 0.945
# Step 355, Minibatch Loss= 0.1288, Training Accuracy= 0.960
# Step 356, Minibatch Loss= 0.1273, Training Accuracy= 0.955
# Step 357, Minibatch Loss= 0.1733, Training Accuracy= 0.935
# Step 358, Minibatch Loss= 0.0686, Training Accuracy= 0.985
# Step 359, Minibatch Loss= 0.1150, Training Accuracy= 0.955
# Step 360, Minibatch Loss= 0.1085, Training Accuracy= 0.960
# Step 361, Minibatch Loss= 0.1468, Training Accuracy= 0.950
# Step 362, Minibatch Loss= 0.0987, Training Accuracy= 0.970
# Step 363, Minibatch Loss= 0.1297, Training Accuracy= 0.955
# Step 364, Minibatch Loss= 0.1532, Training Accuracy= 0.945
# Step 365, Minibatch Loss= 0.0999, Training Accuracy= 0.960
# Step 366, Minibatch Loss= 0.1438, Training Accuracy= 0.945
# Step 367, Minibatch Loss= 0.0874, Training Accuracy= 0.985
# Step 368, Minibatch Loss= 0.1369, Training Accuracy= 0.965
# Step 369, Minibatch Loss= 0.1973, Training Accuracy= 0.940
# Step 370, Minibatch Loss= 0.2236, Training Accuracy= 0.915
# Step 371, Minibatch Loss= 0.1258, Training Accuracy= 0.955
# Step 372, Minibatch Loss= 0.1675, Training Accuracy= 0.955
# Step 373, Minibatch Loss= 0.1589, Training Accuracy= 0.945
# Step 374, Minibatch Loss= 0.1255, Training Accuracy= 0.970
# Step 375, Minibatch Loss= 0.1167, Training Accuracy= 0.965
# Step 376, Minibatch Loss= 0.1400, Training Accuracy= 0.945
# Step 377, Minibatch Loss= 0.2252, Training Accuracy= 0.915
# Step 378, Minibatch Loss= 0.2001, Training Accuracy= 0.940
# Step 379, Minibatch Loss= 0.2260, Training Accuracy= 0.945
# Step 380, Minibatch Loss= 0.1352, Training Accuracy= 0.965
# Step 381, Minibatch Loss= 0.1535, Training Accuracy= 0.940
# Step 382, Minibatch Loss= 0.1329, Training Accuracy= 0.960
# Step 383, Minibatch Loss= 0.1305, Training Accuracy= 0.960
# Step 384, Minibatch Loss= 0.1344, Training Accuracy= 0.945
# Step 385, Minibatch Loss= 0.2163, Training Accuracy= 0.930
# Step 386, Minibatch Loss= 0.0942, Training Accuracy= 0.965
# Step 387, Minibatch Loss= 0.1053, Training Accuracy= 0.950
# Step 388, Minibatch Loss= 0.1640, Training Accuracy= 0.930
# Step 389, Minibatch Loss= 0.1710, Training Accuracy= 0.950
# Step 390, Minibatch Loss= 0.1370, Training Accuracy= 0.960
# Step 391, Minibatch Loss= 0.1264, Training Accuracy= 0.960
# Step 392, Minibatch Loss= 0.1288, Training Accuracy= 0.955
# Step 393, Minibatch Loss= 0.1031, Training Accuracy= 0.965
# Step 394, Minibatch Loss= 0.1492, Training Accuracy= 0.960
# Step 395, Minibatch Loss= 0.1792, Training Accuracy= 0.940
# Step 396, Minibatch Loss= 0.1199, Training Accuracy= 0.955
# Step 397, Minibatch Loss= 0.2432, Training Accuracy= 0.920
# Step 398, Minibatch Loss= 0.1406, Training Accuracy= 0.940
# Step 399, Minibatch Loss= 0.0862, Training Accuracy= 0.980
# Step 400, Minibatch Loss= 0.1412, Training Accuracy= 0.940
# Step 401, Minibatch Loss= 0.3107, Training Accuracy= 0.950
# Step 402, Minibatch Loss= 0.1271, Training Accuracy= 0.955
# Step 403, Minibatch Loss= 0.2482, Training Accuracy= 0.925
# Step 404, Minibatch Loss= 0.1628, Training Accuracy= 0.945
# Step 405, Minibatch Loss= 0.1042, Training Accuracy= 0.975
# Step 406, Minibatch Loss= 0.2073, Training Accuracy= 0.920
# Step 407, Minibatch Loss= 0.1365, Training Accuracy= 0.950
# Step 408, Minibatch Loss= 0.1823, Training Accuracy= 0.930
# Step 409, Minibatch Loss= 0.0966, Training Accuracy= 0.975
# Step 410, Minibatch Loss= 0.1690, Training Accuracy= 0.935
# Step 411, Minibatch Loss= 0.1581, Training Accuracy= 0.940
# Step 412, Minibatch Loss= 0.1495, Training Accuracy= 0.950
# Step 413, Minibatch Loss= 0.1428, Training Accuracy= 0.955
# Step 414, Minibatch Loss= 0.1542, Training Accuracy= 0.940
# Step 415, Minibatch Loss= 0.1425, Training Accuracy= 0.940
# Step 416, Minibatch Loss= 0.1260, Training Accuracy= 0.935
# Step 417, Minibatch Loss= 0.1851, Training Accuracy= 0.945
# Step 418, Minibatch Loss= 0.0926, Training Accuracy= 0.965
# Step 419, Minibatch Loss= 0.1324, Training Accuracy= 0.960
# Step 420, Minibatch Loss= 0.1075, Training Accuracy= 0.960
# Step 421, Minibatch Loss= 0.1672, Training Accuracy= 0.945
# Step 422, Minibatch Loss= 0.1917, Training Accuracy= 0.915
# Step 423, Minibatch Loss= 0.0918, Training Accuracy= 0.965
# Step 424, Minibatch Loss= 0.2170, Training Accuracy= 0.925
# Step 425, Minibatch Loss= 0.1060, Training Accuracy= 0.965
# Step 426, Minibatch Loss= 0.1240, Training Accuracy= 0.960
# Step 427, Minibatch Loss= 0.1111, Training Accuracy= 0.960
# Step 428, Minibatch Loss= 0.1554, Training Accuracy= 0.935
# Step 429, Minibatch Loss= 0.1613, Training Accuracy= 0.955
# Step 430, Minibatch Loss= 0.1605, Training Accuracy= 0.955
# Step 431, Minibatch Loss= 0.1166, Training Accuracy= 0.960
# Step 432, Minibatch Loss= 0.1866, Training Accuracy= 0.925
# Step 433, Minibatch Loss= 0.1439, Training Accuracy= 0.940
# Step 434, Minibatch Loss= 0.1593, Training Accuracy= 0.925
# Step 435, Minibatch Loss= 0.1516, Training Accuracy= 0.945
# Step 436, Minibatch Loss= 0.1169, Training Accuracy= 0.950
# Step 437, Minibatch Loss= 0.1314, Training Accuracy= 0.955
# Step 438, Minibatch Loss= 0.1193, Training Accuracy= 0.950
# Step 439, Minibatch Loss= 0.1172, Training Accuracy= 0.955
# Step 440, Minibatch Loss= 0.0791, Training Accuracy= 0.990
# Step 441, Minibatch Loss= 0.1554, Training Accuracy= 0.945
# Step 442, Minibatch Loss= 0.1708, Training Accuracy= 0.940
# Step 443, Minibatch Loss= 0.1223, Training Accuracy= 0.965
# Step 444, Minibatch Loss= 0.1391, Training Accuracy= 0.960
# Step 445, Minibatch Loss= 0.0804, Training Accuracy= 0.970
# Step 446, Minibatch Loss= 0.1369, Training Accuracy= 0.945
# Step 447, Minibatch Loss= 0.1216, Training Accuracy= 0.950
# Step 448, Minibatch Loss= 0.1387, Training Accuracy= 0.950
# Step 449, Minibatch Loss= 0.1600, Training Accuracy= 0.935
# Step 450, Minibatch Loss= 0.0993, Training Accuracy= 0.970
# Step 451, Minibatch Loss= 0.1382, Training Accuracy= 0.955
# Step 452, Minibatch Loss= 0.1330, Training Accuracy= 0.955
# Step 453, Minibatch Loss= 0.2021, Training Accuracy= 0.940
# Step 454, Minibatch Loss= 0.0906, Training Accuracy= 0.970
# Step 455, Minibatch Loss= 0.0927, Training Accuracy= 0.945
# Step 456, Minibatch Loss= 0.1291, Training Accuracy= 0.960
# Step 457, Minibatch Loss= 0.1009, Training Accuracy= 0.960
# Step 458, Minibatch Loss= 0.0919, Training Accuracy= 0.960
# Step 459, Minibatch Loss= 0.1320, Training Accuracy= 0.960
# Step 460, Minibatch Loss= 0.1475, Training Accuracy= 0.960
# Step 461, Minibatch Loss= 0.0893, Training Accuracy= 0.965
# Step 462, Minibatch Loss= 0.1224, Training Accuracy= 0.960
# Step 463, Minibatch Loss= 0.1843, Training Accuracy= 0.955
# Step 464, Minibatch Loss= 0.2298, Training Accuracy= 0.930
# Step 465, Minibatch Loss= 0.1086, Training Accuracy= 0.955
# Step 466, Minibatch Loss= 0.1367, Training Accuracy= 0.950
# Step 467, Minibatch Loss= 0.2585, Training Accuracy= 0.925
# Step 468, Minibatch Loss= 0.1313, Training Accuracy= 0.935
# Step 469, Minibatch Loss= 0.1692, Training Accuracy= 0.945
# Step 470, Minibatch Loss= 0.1300, Training Accuracy= 0.955
# Step 471, Minibatch Loss= 0.1477, Training Accuracy= 0.950
# Step 472, Minibatch Loss= 0.1048, Training Accuracy= 0.965
# Step 473, Minibatch Loss= 0.1151, Training Accuracy= 0.955
# Step 474, Minibatch Loss= 0.1272, Training Accuracy= 0.955
# Step 475, Minibatch Loss= 0.0911, Training Accuracy= 0.975
# Step 476, Minibatch Loss= 0.1267, Training Accuracy= 0.965
# Step 477, Minibatch Loss= 0.1180, Training Accuracy= 0.955
# Step 478, Minibatch Loss= 0.1504, Training Accuracy= 0.945
# Step 479, Minibatch Loss= 0.1295, Training Accuracy= 0.955
# Step 480, Minibatch Loss= 0.1242, Training Accuracy= 0.955
# Step 481, Minibatch Loss= 0.0901, Training Accuracy= 0.955
# Step 482, Minibatch Loss= 0.1350, Training Accuracy= 0.960
# Step 483, Minibatch Loss= 0.1489, Training Accuracy= 0.945
# Step 484, Minibatch Loss= 0.1625, Training Accuracy= 0.920
# Step 485, Minibatch Loss= 0.1250, Training Accuracy= 0.950
# Step 486, Minibatch Loss= 0.1193, Training Accuracy= 0.970
# Step 487, Minibatch Loss= 0.1451, Training Accuracy= 0.945
# Step 488, Minibatch Loss= 0.1136, Training Accuracy= 0.965
# Step 489, Minibatch Loss= 0.1292, Training Accuracy= 0.950
# Step 490, Minibatch Loss= 0.0990, Training Accuracy= 0.975
# Step 491, Minibatch Loss= 0.1456, Training Accuracy= 0.955
# Step 492, Minibatch Loss= 0.0717, Training Accuracy= 0.970
# Step 493, Minibatch Loss= 0.1726, Training Accuracy= 0.965
# Step 494, Minibatch Loss= 0.1622, Training Accuracy= 0.960
# Step 495, Minibatch Loss= 0.1187, Training Accuracy= 0.945
# Step 496, Minibatch Loss= 0.1612, Training Accuracy= 0.955
# Step 497, Minibatch Loss= 0.2235, Training Accuracy= 0.920
# Step 498, Minibatch Loss= 0.1011, Training Accuracy= 0.965
# Step 499, Minibatch Loss= 0.2922, Training Accuracy= 0.935
# Step 500, Minibatch Loss= 0.2046, Training Accuracy= 0.955
# Optimization Finished!
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node input_producer/input_producer/input_producer_EnqueueMany}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# Exception in thread QueueRunnerThread-input_producer/input_producer-input_producer/input_producer/input_producer_EnqueueMany:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node input_producer/input_producer/input_producer_EnqueueMany}}]]
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]
#
#
#
#
# Exception in thread QueueRunnerThread-batch/fifo_queue-batch/fifo_queue_enqueue:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py", line 257, in _run
#     enqueue_callable()
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1257, in _single_operation_run
#     self._call_tf_sessionrun(None, {}, [], target_list, None)
#   File "/usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1407, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.CancelledError: Enqueue operation was cancelled
# 	 [[{{node batch/fifo_queue_enqueue}}]]

# %%
# Create model
def conv_net(x, n_classes, dropout, reuse, is_training):
    # Define a scope for reusing the variables
    with tf.variable_scope('ConvNet', reuse=reuse):

        # Convolution Layer with 32 filters and a kernel size of 5
        conv1 = tf.layers.conv2d(x, 64, 5, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with kernel size of 2 and strides of 2
        conv1 = tf.layers.max_pooling2d(conv1, 5, 3)

        # Convolution Layer with 32 filters and a kernel size of 5
        conv2 = tf.layers.conv2d(conv1, 64, 3, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with kernel size of 2 and strides of 2 
        conv2 = tf.layers.max_pooling2d(conv2, 5, 3)
        
        conv3 = tf.layers.conv2d(conv2, 128, 3)
        conv3 = tf.layers.max_pooling2d(conv3, 3, 2)

        # Flatten the data to a 1-D vector for the fully connected layer
        fc1 = tf.contrib.layers.flatten(conv3)

        # Fully connected layer (in contrib folder for now)
        fc1 = tf.layers.dense(fc1, 1024)
        # Apply Dropout (if is_training is False, dropout is not applied)
        #fc1 = tf.layers.dropout(fc1, rate=dropout, training=is_training)

        # Output layer, class prediction
        out = tf.layers.dense(fc1, n_classes)
        # Because 'softmax_cross_entropy_with_logits' already apply softmax,
        # we only apply softmax to testing network
        out = tf.nn.softmax(out) if not is_training else out

    return out

# %%
def read_images(dataset_path, mode, batch_size):
    imagepaths, labels = list(), list()
    if mode == 'file':
        # Read dataset file
        with open(dataset_path) as f:
            data = f.read().splitlines()
        for d in data:
            imagepaths.append(d.split(' ')[0])
            labels.append(int(d.split(' ')[1]))
    elif mode == 'folder':
        # An ID will be affected to each sub-folders by alphabetical order
        label = 0
        # List the directory
        try:  # Python 2
            classes = sorted(os.walk(dataset_path).next()[1])
        except Exception:  # Python 3
            classes = sorted(os.walk(dataset_path).__next__()[1])
        # List each sub-directory (the classes)
        for c in classes:
            c_dir = os.path.join(dataset_path, c)
            try:  # Python 2
                walk = os.walk(c_dir).next()
            except Exception:  # Python 3
                walk = os.walk(c_dir).__next__()
            # Add each image to the training set
            for sample in walk[2]:
                # Only keeps jpeg images
                if sample.endswith('.png') or sample.endswith('.jpeg'):
                    imagepaths.append(os.path.join(c_dir, sample))
                    labels.append(label)
            label += 1
    else:
        raise Exception("Unknown mode.")

    # Convert to Tensor
    imagepaths = tf.convert_to_tensor(imagepaths, dtype=tf.string)
    labels = tf.convert_to_tensor(labels, dtype=tf.int32)
    # Build a TF Queue, shuffle data
    image, label = tf.train.slice_input_producer([imagepaths, labels],
                                                 shuffle=True)
    
    

    # Read images from disk
    image = tf.read_file(image)
    image = tf.image.decode_png(image, channels=CHANNELS)

    # Resize images to a common size
    image = tf.image.resize_images(image, [IMG_HEIGHT, IMG_WIDTH])

    # Normalize
    image = image * 1.0/127.5 - 1.0

    # Create batches
    X, Y = tf.train.batch([image, label], batch_size=batch_size,
                          capacity=batch_size * 8,
                          num_threads=4)

    return X, Y

# %%
from PIL import Image
import torchvision.transforms.functional as TF

# %%
image = Image.open('/s/bach/g/under/cutreap/Desktop/cs445/cell_images/Parasitized/C33P1thinF_IMG_20150619_115740a_cell_161.png')

# %%
x = TF.to_tensor(image)
x.unsqueeze_(0)
print(x.shape)
# Out:
# torch.Size([1, 3, 127, 124])

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

from tensorflow.keras import datasets, layers, models

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3-4.4.0/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 33s 546us/sample - loss: 0.0181 - acc: 0.9944
# Epoch 2/5
# 60000/60000 [==============================] - 35s 576us/sample - loss: 0.0132 - acc: 0.9958
# Epoch 3/5
# 60000/60000 [==============================] - 33s 544us/sample - loss: 0.0117 - acc: 0.9961
# Epoch 4/5
# 60000/60000 [==============================] - 29s 489us/sample - loss: 0.0095 - acc: 0.9969
# Epoch 5/5
# 60000/60000 [==============================] - 28s 474us/sample - loss: 0.0097 - acc: 0.9970

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 2s 159us/sample - loss: 0.0387 - acc: 0.9912

# %%
print(test_acc)
# Out:
# 0.9912
